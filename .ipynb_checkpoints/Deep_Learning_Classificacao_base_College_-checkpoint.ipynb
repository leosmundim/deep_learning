# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Deep Learning (Redes Neurais Multicamadas)
#
# Exemplo da AULA - SÉRIES TEMPORAIS - Prof. Jerônymo Marcondes Pinto <br>
# AULA MINISTRADA EM R E TRADUZIDA PARA PYTHON COMO FORMA DE APRENDIZADO.
#
# Rede Neural de Classificação
#
# ### Base College

# %%
df = pd.read_csv(r'bases\college.csv', sep=",")
df
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 0           52         2885          537      7440        3300    450
# 1           29         2683         1227     12280        6450    750
# 2           50         1036           99     11250        3750    400
# 3           89          510           63     12960        5450    450
# 4           44          249          869      7560        4120    800
# ..         ...          ...          ...       ...         ...    ...
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# ..        ...  ...       ...        ...          ...     ...        ...
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
# [777 rows x 19 columns]

# %%
df = pd.get_dummies(df, columns=['Private'], drop_first=True)

# %%
df
# Out:
#                             College   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University   1660    1232     721         23
# 1                Adelphi University   2186    1924     512         16
# 2                    Adrian College   1428    1097     336         22
# 3               Agnes Scott College    417     349     137         60
# 4         Alaska Pacific University    193     146      55         16
# ..                              ...    ...     ...     ...        ...
# 772         Worcester State College   2197    1515     543          4
# 773               Xavier University   1959    1805     695         24
# 774  Xavier University of Louisiana   2097    1915     695         34
# 775                 Yale University  10705    2453    1317         95
# 776    York College of Pennsylvania   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 0           52         2885          537      7440        3300    450
# 1           29         2683         1227     12280        6450    750
# 2           50         1036           99     11250        3750    400
# 3           89          510           63     12960        5450    450
# 4           44          249          869      7560        4120    800
# ..         ...          ...          ...       ...         ...    ...
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# ..        ...  ...       ...        ...          ...     ...        ...
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
#      Private_Yes
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 772            0
# 773            1
# 774            1
# 775            1
# 776            1
#
# [777 rows x 19 columns]

# %% [markdown]
# ## Aplicando Padronização

# %%
# Selciona Dados

df = df.iloc[:,1:]

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_std = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df_std
# Out:
#          Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0    0.032887  0.044177  0.107913   0.231579   0.472527     0.087164
# 1    0.043842  0.070531  0.075035   0.157895   0.219780     0.080752
# 2    0.028055  0.039036  0.047349   0.221053   0.450549     0.028473
# 3    0.006998  0.010549  0.016045   0.621053   0.879121     0.011776
# 4    0.002333  0.002818  0.003146   0.157895   0.384615     0.003492
# ..        ...       ...       ...        ...        ...          ...
# 772  0.044071  0.054955  0.079912   0.031579   0.186813     0.093639
# 773  0.039114  0.065999  0.103823   0.242105   0.417582     0.086021
# 774  0.041989  0.070188  0.103823   0.347368   0.571429     0.084243
# 775  0.221273  0.090677  0.201667   0.989474   0.989011     0.161186
# 776  0.060567  0.067903  0.103193   0.284211   0.593407     0.090433
#
#      P.Undergrad  Outstate  Room.Board     Books  Personal       PhD  \
# 0       0.024548  0.263430    0.239596  0.157754  0.297710  0.652632
# 1       0.056148  0.513430    0.736129  0.291444  0.190840  0.221053
# 2       0.004488  0.460227    0.310530  0.135472  0.139695  0.473684
# 3       0.002839  0.548554    0.578499  0.157754  0.095420  0.884211
# 4       0.039753  0.269628    0.368852  0.313725  0.190840  0.715789
# ..           ...       ...         ...       ...       ...       ...
# 772     0.092878  0.230217    0.334174  0.180036  0.145038  0.547368
# 773     0.050653  0.474174    0.501261  0.224599  0.152672  0.684211
# 774     0.007557  0.235537    0.381463  0.232175  0.081069  0.621053
# 775     0.003755  0.903926    0.745586  0.237968  0.284733  0.926316
# 776     0.079002  0.136880    0.280580  0.180036  0.152672  0.705263
#
#      Terminal  S.F.Ratio  perc.alumni    Expend  Grad.Rate  Private_Yes
# 0    0.710526   0.418231     0.187500  0.072671   0.462963          1.0
# 1    0.078947   0.260054     0.250000  0.138387   0.425926          1.0
# 2    0.552632   0.278820     0.468750  0.104605   0.407407          1.0
# 3    0.960526   0.139410     0.578125  0.298415   0.453704          1.0
# 4    0.631579   0.252011     0.031250  0.145833   0.046296          1.0
# ..        ...        ...          ...       ...        ...          ...
# 772  0.473684   0.495979     0.218750  0.024186   0.277778          0.0
# 773  0.671053   0.289544     0.484375  0.113164   0.675926          1.0
# 774  0.671053   0.319035     0.312500  0.096839   0.361111          1.0
# 775  0.947368   0.088472     0.765625  0.701265   0.824074          1.0
# 776  0.671053   0.418231     0.437500  0.024940   0.824074          1.0
#
# [777 rows x 18 columns]

# %%
df_std.Private_Yes.value_counts()
# Out:
# 1.0    565
# 0.0    212
# Name: Private_Yes, dtype: int64

# %% [markdown]
# ## Aplicando Modelo de Redes Neurais de Classificação

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(df_std.drop('Private_Yes', axis=1), 
                                                    df_std['Private_Yes'], 
                                                    random_state=0, 
                                                    test_size=0.30)

# %%
len(X_train), len(X_test)
# Out:
# (543, 234)

# %% [markdown]
# Documentação: https://www.tensorflow.org/api_docs/python/tf/keras/activations
#
# Documentação Sequential: https://www.tensorflow.org/api_docs/python/tf/keras/Sequential
#
# Referência: https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
modelo = Sequential([
    Dense(17,activation = 'relu'),
    Dense(5,activation = 'relu'),
    Dense(4,activation = 'relu'),
    Dense(1,activation = 'sigmoid')
])

# %%
modelo.compile(optimizer = 'ADAM', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
history = modelo.fit(X_train, y_train, batch_size=543, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 616ms/step - loss: 0.7418 - accuracy: 0.2726
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7375 - accuracy: 0.2762
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7333 - accuracy: 0.2873
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7292 - accuracy: 0.2836
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7251 - accuracy: 0.2947
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7212 - accuracy: 0.3057
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7174 - accuracy: 0.3204
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7138 - accuracy: 0.3333
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7103 - accuracy: 0.3536
# Epoch 10/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7069 - accuracy: 0.3665
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7037 - accuracy: 0.4070
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7008 - accuracy: 0.4622
# Epoch 13/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6982 - accuracy: 0.5120
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6960 - accuracy: 0.5562
# Epoch 15/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.5838
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.6114
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.6575
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.6796
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6892 - accuracy: 0.7053
# Epoch 20/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.7164
# Epoch 21/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.7385
# Epoch 22/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.7440
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.7477
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.7551
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.7643
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.7661
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6838 - accuracy: 0.7680
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.7680
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6823 - accuracy: 0.7698
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.7698
# Epoch 31/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.7698
# Epoch 32/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6796 - accuracy: 0.7716
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6787 - accuracy: 0.7698
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.7698
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.7716
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6756 - accuracy: 0.7716
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.7790
# Epoch 38/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6733 - accuracy: 0.7864
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.7919
# Epoch 40/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6709 - accuracy: 0.7974
# Epoch 41/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6695 - accuracy: 0.8029
# Epoch 42/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.8066
# Epoch 43/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.8140
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.8250
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6641 - accuracy: 0.8343
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.8324
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6612 - accuracy: 0.8361
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6598 - accuracy: 0.8379
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6583 - accuracy: 0.8398
# Epoch 50/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6569 - accuracy: 0.8471
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.8564
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6539 - accuracy: 0.8582
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6524 - accuracy: 0.8619
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6509 - accuracy: 0.8619
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6494 - accuracy: 0.8619
# Epoch 56/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6479 - accuracy: 0.8619
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6463 - accuracy: 0.8619
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6448 - accuracy: 0.8656
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.8637
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.8674
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.8656
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.8692
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6366 - accuracy: 0.8748
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6349 - accuracy: 0.8729
# Epoch 65/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.8729
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6314 - accuracy: 0.8729
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6296 - accuracy: 0.8729
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.8729
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.8711
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.8729
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6223 - accuracy: 0.8748
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6204 - accuracy: 0.8766
# Epoch 73/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.8766
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.8785
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6147 - accuracy: 0.8821
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6128 - accuracy: 0.8840
# Epoch 77/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6108 - accuracy: 0.8840
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.8840
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6068 - accuracy: 0.8840
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6048 - accuracy: 0.8877
# Epoch 81/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6027 - accuracy: 0.8913
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.8913
# Epoch 83/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5986 - accuracy: 0.8877
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.8877
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5944 - accuracy: 0.8877
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.8858
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5901 - accuracy: 0.8858
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.8877
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5858 - accuracy: 0.8877
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5836 - accuracy: 0.8913
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5814 - accuracy: 0.8913
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5791 - accuracy: 0.8913
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.8913
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.8913
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.8913
# Epoch 96/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5700 - accuracy: 0.8932
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5677 - accuracy: 0.8932
# Epoch 98/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5654 - accuracy: 0.8932
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5631 - accuracy: 0.8969
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5607 - accuracy: 0.8969

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'accuracy']].plot();
print("Max Accuracy: {}".format(history_df['accuracy'].max()))
# Out:
# Max Accuracy: 0.8968692421913147

# %%
y_hat = (pd.DataFrame(modelo.predict(X_test), columns=['y_hat']).reset_index().drop('index', axis=1).round())
y_hat
# Out:
# 8/8 [==============================] - 0s 709us/step
#      y_hat
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# ..     ...
# 229    1.0
# 230    1.0
# 231    1.0
# 232    1.0
# 233    1.0
#
# [234 rows x 1 columns]

# %% [markdown]
# ## Acurácia

# %%
from sklearn.metrics import confusion_matrix

cutoff = 0.5

#predicted_classes = (step_fidelidade.fittedvalues > cutoff).astype(int)

cm = pd.DataFrame(confusion_matrix(y_test, y_hat), 
                  index=['0', '1'],
                  columns=['0', '1'])
cm['Real'] = cm.T.sum()

# %%
cm
# Out:
#     0    1  Real
# 0  47   15    62
# 1   2  170   172

# %%
(47+170)/234
# Out:
# 0.9273504273504274

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_hat)
# Out:
# 0.9273504273504274

# %% [markdown]
# ## Comparando com modelo de Árvore de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier

# Aplicando o Modelo
model_tree = DecisionTreeClassifier(max_depth = 30, 
                              #ccp_alpha=0.038362, 
                              min_samples_split=2)
reg_tree_poda = model_tree.fit(X_train, y_train)

# %%
accuracy_score(y_test,reg_tree_poda.predict(X_test))
# Out:
# 0.9188034188034188
